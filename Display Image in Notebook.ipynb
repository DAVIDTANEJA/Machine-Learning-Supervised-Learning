# %% [markdown]
# ## Different methods to display Image

# %% [markdown]
# ### 1.

# %%
import pandas as pd
from IPython.display import Image, HTML

df = pd.DataFrame(['<img src="image-11-300x217.png"/>'])       # in df list can take more images 

HTML(df.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td><img src="image-11-300x217.png"/></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 2. used as title , also markdown this cell before Run

# %%
# ![title](image-11-300x217.png)

# %% [markdown]
# ![title](image-11-300x217.png)

# %% [markdown]
# ### 3.

# %%
from IPython.display import Image

Image(filename="image-11-300x217.png")    # use also : width=100, height=100

# %% [markdown]
# ### 4. Use directly using < img src > and cell should be Markdown

# %%
# <img src="image-11-300x217.png">

# %% [markdown]
# <img src="image-11-300x217.png">

# %% [markdown]
# ### 5.

# %%
# %%html
#
# <img src="image-11-300x217.png">
# Out:
# <img src="image-11-300x217.png">
